# %% [markdown]
# Pandas -2
#
# Titanic Veri Seti Üzerinde Örnek Veri Analizi

# %% [markdown]
# ![image.png](attachment:1e85eebd-578d-49da-ad35-a3f65e0ebc33.png)

# %% [markdown]
# ### 1. Kütüphaneleri Yükle

# %%
import pandas as pd

# %% [markdown]
# ### 2. Veri Setini Yükle

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 3073-49B7
#
#  Directory of C:\Users\murat\Documents\EcodationBootcamp\day8
#
# 15.08.2024  21:41    <DIR>          .
# 15.08.2024  21:35    <DIR>          ..
# 15.08.2024  21:36    <DIR>          .ipynb_checkpoints
# 15.08.2024  21:41           451.608 Pandas2.ipynb
# 07.06.2024  10:56            61.194 train.csv
#                2 File(s)        512.802 bytes
#                3 Dir(s)  91.554.816.000 bytes free

# %%
#pandas ile csv dodyasını okuyarak df e aktracağız
# data veya df 
df=pd.read_csv('train.csv')

# %% [markdown]
# ### 3. Keşifsel Veri Analizi  (Exploratory Data Analysis EDA)

# %% [markdown]
# #### head()

# %%
df.head() # Veri setinin ilk 5 satırını listeler
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [raw]
# SibSp (Sibling Spouse): gemide bulunan kardeş (sibling) ve eş (spouse) sayısını temsil eder. Yani bu değer, yolcunun gemideki aile bağlarını gösterir.
# Parch (Parent Child): yolcunun Titanik gemisindeki yolculuğu sırasında gemide bulunan ebeveyn (parent) ve çocuk (child) sayısını temsil eder.
# Fare: Bilet ücreti
# Embarked: Yolcunun bindiği liman

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#### tail()
df.tail() # veris setindeki son 5 satır
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# #### info()

# %% [raw]
# satır sayısı
# sütun sayısı
# veri türü dtypes: float64(2), int64(5), object(5)
# eksik olmayan veri sayısını getirir

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #### describe()

# %%
df.describe() # parametre verilmeden yazıldığında sayısal sütunlara/özelliklere ilkişkin betimsel istatistikleri verir
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='all') #sadece sayısal değil tüm sütunlar için betimsel sitatristikler verir
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [raw]
# Sayısal sütunlar için
# mean : Ortalama
# std : Standart sapma
# min : Minimum değer
# veriyi küçükten büyüğe sıraladık
# %25 : veriyi sıraladığımızda veri saysının %25 ine geldğimizdeki değer
# %50 : veriyi sıraladığımızda veri saysının %50 ine geldğimizdeki değer
# %75 : veriyi sıraladığımızda veri saysının %75 ine geldğimizdeki değer
# max : Maksimum değer
# count : veri sayısı

# %% [raw]
# kategorik değerler
# unique : kategorilerin etiketleri, adları
# top     : en çok tekrar eden değer
# freq    : kategorideki sıklık

# %% [markdown]
# ### isnull().sum() eksik veri sayısı

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Sütun seçelim

# %%
df['Name'] #sütun isimler case sensetive büyük harf küçük harf duyarlı
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(df['Name']) # tek bir sütun seçildiğinde bu bir seridir
# Out:
# pandas.core.series.Series

# %%
df[['Name','Age']] # iç içe liste birden fazla sütunu seçmek için
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
type(df[['Name','Age']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.Age #Tek bir sütunu seçmek için df.dutunadi kullanabilirsiniz
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
#En yaşlı yolcu
# En yaşlı demek yaşı en büyük demek
df['Age'].max()
# Out:
# 80.0

# %%
#filtreleme
df[df['Age']==80]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
df[df['Age']==df['Age'].max()]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
#en genç yolcu
df[df['Age']==df['Age'].min()]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C

# %%
#yaş ortalaması
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
#birden fazla sütun için ortalama
df[['Age','Fare']].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
df['Age'].std()
# Out:
# 14.526497332334044

# %%
df[['Age','Fare']].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %% [markdown]
# ### Veri Setini Filtreleme

# %%
#Yaşı 50 ye eşit veya küçük olanlar
df[df['Age']<=50] # df[df[sutunadi]<=50 'koşul']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df[df['Age']<=50])
# Out:
# 650

# %%
#birden fazla koşul
# koşul(1) & (Koşul2) 50 yaşın altındaki erkekler
df[(df['Age']<=50) & (df['Sex']=='male')]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# 13            14         0       3     Andersson, Mr. Anders Johan  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# ...

# %%
df_erkek_k50=df[(df['Age']<=50) & (df['Sex']=='male')]
df_erkek_k50
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# 13            14         0       3     Andersson, Mr. Anders Johan  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# ...

# %% [markdown]
# ### Kategorik İşlemler

# %%
#df.Sex.value_counts() kadin ve erkek sayisini ayri ayri verir
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts(normalize=True) # oransal oalrak % olarak görme
# Out:
# Sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
#Veri görselleştirme
df['Sex'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot.pie(autopct='%.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.Sex.isnull().sum()
# Out:
# 0

# %%
df['Embarked'].unique() # kategorielrin adları
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Embarked'].nunique() # bu sütunda kaç farklı değer var
# Out:
# 3

# %%
df['Embarked'].value_counts(normalize=True)
# Out:
# Embarked
# S    0.724409
# C    0.188976
# Q    0.086614
# Name: proportion, dtype: float64

# %%
df['Embarked'].value_counts(normalize=True).plot.pie() # pasta grafiği için plot.pie() kullanılır
# Out:
# <Axes: ylabel='proportion'>

# %%
#df['Embarked'].value_counts(normalize=True).plot()
# Out:
# <Axes: xlabel='Embarked'>

# %% [markdown]
# ### DataFrame satır ve sütun seçme

# %%
df.iloc[0] #iloc = index location index no 0 olan birinci kişi/kayıt
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
#df.head()
df.iloc[0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[:5,3] #satır sütun seçme Name sütunun indexini girerek belirtebiliriz
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
df.iloc[:5,3:6] #Adı cinsiyeti ve yaşı seçebiliriz
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df.loc[0:5,'Name':'Age'] # loc da sütun için isimler belirtilir.
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN

# %%
df.loc[0:5,['Name', 'Sex', 'Age']]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN

# %% [markdown]
# ### groupby()

# %%
### Cinsiyete Göre hayatta kalma

# %%
df['Survived'].groupby(df['Sex']).value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
df['Survived'].groupby(df['Sex']).value_counts(normalize=True)
# Out:
# Sex     Survived
# female  1           0.742038
#         0           0.257962
# male    0           0.811092
#         1           0.188908
# Name: proportion, dtype: float64

# %%
df['Survived'].groupby(df['Sex']).value_counts(normalize=True).plot.bar()
# Out:
# <Axes: xlabel='Sex,Survived'>

# %%
df['Survived'].groupby(df['Sex']).value_counts().plot.bar()
# Out:
# <Axes: xlabel='Sex,Survived'>

# %%
import seaborn as sns
# anaconda üzerinde kurulu
# pip install seaborn

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
sns.countplot(x='Survived', hue='Sex', data=df) #x eksneninde hayatta kalmayı cinsiet değişkenine göre görselleştir
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
#pclass ve hayatta kalma ilişkisi
df['Survived'].groupby(df['Pclass']).value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %%
df['Survived'].groupby(df['Pclass']).value_counts(normalize=True)
# Out:
# Pclass  Survived
# 1       1           0.629630
#         0           0.370370
# 2       0           0.527174
#         1           0.472826
# 3       0           0.757637
#         1           0.242363
# Name: proportion, dtype: float64

# %%
#yolculuk sınıfında cinsiyetlere göre hayatta kalma 
df['Survived'].groupby([df['Pclass'],df['Sex']]).value_counts(normalize=True)
# Out:
# Pclass  Sex     Survived
# 1       female  1           0.968085
#                 0           0.031915
#         male    0           0.631148
#                 1           0.368852
# 2       female  1           0.921053
#                 0           0.078947
#         male    0           0.842593
#                 1           0.157407
# 3       female  0           0.500000
#                 1           0.500000
#         male    0           0.864553
#                 1           0.135447
# Name: proportion, dtype: float64

# %%
df['Survived'].groupby([df['Pclass'],df['Sex']]).value_counts()
# Out:
# Pclass  Sex     Survived
# 1       female  1            91
#                 0             3
#         male    0            77
#                 1            45
# 2       female  1            70
#                 0             6
#         male    0            91
#                 1            17
# 3       female  0            72
#                 1            72
#         male    0           300
#                 1            47
# Name: count, dtype: int64

# %%
#3. sınıf yolculuk yapan erkek
df_3pclass_male=df[(df['Pclass']==3) & (df['Sex']=='male')]

# %%
df_3pclass_male['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.864553
# 1    0.135447
# Name: proportion, dtype: float64

# %%
# kadın erkeklerin yaş istatisitikleri
type(df[['Sex','Age']].groupby('Sex'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df[['Sex','Age']].groupby('Sex').describe()
# Out:
#           Age
#         count       mean        std   min   25%   50%   75%   max
# Sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %%
df[['Sex','Age']].groupby('Sex').mean() # kadın ve erkeklerin yaş ortalmaları
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %% [markdown]
# ![image.png](attachment:ea5ba4b8-307b-44e9-b1cb-b108e376c730.png)

# %%
df.agg(
    {
    'Age':['min','max','median','mean','skew'], #skew çarpıklık demek poztif sağa negatif sola çarpık 
    'Fare':['min', 'max','median','mean', 'skew','sum'] # sum toplam ciro lazım 
    }
)
# Out:
#               Age          Fare
# min      0.420000      0.000000
# max     80.000000    512.329200
# median  28.000000     14.454200
# mean    29.699118     32.204208
# skew     0.389108      4.787317
# sum           NaN  28693.949300

# %%
df['Fare'].sum()
# Out:
# 28693.9493
