# %% [markdown]
# ### Bing Image Downloader

# %%
pip install bing-image-downloader
# Out:
# ...
#   Using cached bing_image_downloader-1.1.2-py3-none-any.whl.metadata (2.8 kB)
# Using cached bing_image_downloader-1.1.2-py3-none-any.whl (5.9 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bing_image_downloader import downloader

# %%
downloader.download('cat', limit=100, adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\murat\Documents\EcodationBootcamp\day11\dataset\cat
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 95 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://get.pxhere.com/photo/animal-pet-kitten-cat-small-mammal-fauna-heal-blue-eye-close-up-nose-whiskers-vertebrate-domestic-lying-tabby-cat-norwegian-forest-cat-ginger-fur-small-to-medium-sized-cats-cat-like-mammal-carnivoran-domestic-short-haired-cat-domestic-long-haired-cat-609263.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Cat03.jpg/1200px-Cat03.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://upload.wikimedia.org/wikipedia/commons/d/d4/Cat_March_2010-1a.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.natgeofe.com/n/548467d8-c5f1-4551-9f58-6817a8d2c45e/NationalGeographic_2572187_3x2.jpg
# [%] File Downloaded !
#
# ...
