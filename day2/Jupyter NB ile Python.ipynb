# %% [markdown]
# # Jupyter NB ile Python Programlama

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1zxg-EOQclx8Kp4ZIjuEjIczTNhA-c-QV?usp=sharing)

# %% [markdown]
# Bu uygulamada Jupyter NB kullanımı anlatılacaktır. Python Programlama diline giriş yapılacaktır.

# %% [markdown]
# Eğer bir kod hücresine normal bir metin eklerseniz hata alırsınız!

# %% [markdown]
# ![image.png](attachment:28aab99e-56cc-4565-a252-3cd4b88a23db.png)

# %% [markdown]
# ![image.png](attachment:a214bf88-1d4d-4698-ae16-9fa68fb0d964.png)

# %% [markdown]
# # Başlık 1
# ## Başlık 2
# ### Başlık 3
# #### Başlık 4

# %% [markdown]
# # Metin Biçimlendirme
#
# **Bold**
#
# *İtalik*
#
# [Google](https://www.google.com)
#
# 1. İrem Zehra
# 2. Gülceren
#
# 😀😀😀
#
# Blok eklemek
# > Blok 1
# >
# > Blok 2
# >
# > Blok 3

# %% [markdown]
# ```
# # Bu, kod olarak biçimlendirilmiştir
# `````

# %% [markdown]
# ## Latex Kullanımı

# %% [markdown]
# $$c=\sqrt{a^2+b^2}$$

# %% [markdown]
# $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$

# %%
from IPython.display import display, Math, Latex
display(Math(r'F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx'))
# Out:
# $\displaystyle F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$

# %% [markdown]
# # Komut Satırı İşlemleri

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 3073-49B7
#
#  Directory of C:\Users\murat\Documents\EcodationBootcamp\day2
#
# 01.08.2024  22:43    <DIR>          .
# 01.08.2024  22:03    <DIR>          ..
# 01.08.2024  22:03    <DIR>          .ipynb_checkpoints
# 01.08.2024  22:43            54.718 Jupyter NB ile Python.ipynb
#                1 File(s)         54.718 bytes
#                3 Dir(s)  99.508.420.608 bytes free

# %% [markdown]
# # Kütüphane Kurulumu

# %%
# Aşağıdaki kütüphaneyi kurmak için # işaretni kaldırarak yorum satırlığından çıkar.

# %%
#pip install pycaret

# %% [markdown]
# # Colab Simgesi ekle

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1zxg-EOQclx8Kp4ZIjuEjIczTNhA-c-QV?usp=sharing)

# %% [markdown]
# [![My GitHub Profile](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSQpRbN3ODAty8IkRiV0HtLrscbJWy5ubgYLw&s)](https://github.com/DrMuratAltun)[![My GitHub Profile](data:image/png;base64,...)](https://kaggle.com/DrMuratAltun)

# %% [markdown]
# [![Open in Colab](https://upload.wikimedia.org/wikipedia/commons/thumb/b/b3/Wikipedia-logo-v2-en.svg/203px-Wikipedia-logo-v2-en.svg.png)](https://colab.research.google.com/drive/1zxg-EOQclx8Kp4ZIjuEjIczTNhA-c-QV?usp=sharing)

# %% [markdown]
# # Latex
# $\alpha$, $\beta$, $\gamma$

# %% [markdown]
#  $\in$, $\subset$, $\cup$, $\cap$

# %% [markdown]
# $\sum_{i=1}^{n}$, $\int_{0}^{\infty}$

# %% [markdown]
# $$\int_{a}^{b} f(x) dx = F(b) - F(a)$$

# %% [raw]
# Başlıklar: <h1>, <h2>, <h3>, ...
# Paragraf: <p>
# Kalın: <strong> veya <b>
# İtalik: <em> veya <i>
# Liste: <ul>, <ol>, <li>

# %% [markdown]
# <h2>Veri Bilimi Konuları</h2>
# <ul>
#   <li>Veri Analizi</li>
#   <li>Makine Öğrenmesi</li>
#   <li>Derin Öğrenme</li>
# </ul>

# %% [raw]
# Ortalama süre (mean): 33.1 mikrosaniye (μs)
# Standart sapma (std. dev.): 1.69 mikrosaniye (μs)

# %%
# Bir fonksiyonun çalışma süresini ölç
# %timeit sum(range(1000000))
# Out:
# 90.4 ms ± 4.83 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# Matplotlib grafiklerini inline göster
# %matplotlib inline

# %%
# %%writefile example.py
def hello():
    print("Hello, World!")
# Out:
# Writing example.py

# %%
# Harici bir Python dosyasını çalıştır
# %run example.py
hello()
# Out:
# Hello, World!
