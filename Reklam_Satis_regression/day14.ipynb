# %% [markdown]
# ## Reklam Harcamalarının Satışlar Üzerine Etkisi

# %% [markdown]
# ![image.png](attachment:438b1d47-05e2-4e2e-b855-b6f9b83433c8.png)

# %% [markdown]
# ![image.png](attachment:529ec4f7-317f-46c6-ab66-aa9aefaf6e65.png)

# %% [markdown]
# ![image.png](attachment:9b763c95-b48d-4deb-9bb1-94e0494e1ecd.png)

# %% [markdown]
# ## Kütüphaneleri Yükle

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# uyarıları filtrele
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Veriyi Yükle

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 3073-49B7
#
#  Directory of C:\Users\murat\Documents\EcodationBootcamp\day14
#
# 12.09.2024  21:49    <DIR>          .
# 12.09.2024  21:47    <DIR>          ..
# 12.09.2024  21:47    <DIR>          .ipynb_checkpoints
# 12.09.2024  21:35             4.063 advertising.xls
# 12.09.2024  21:49         1.693.064 day14.ipynb
#                2 File(s)      1.697.127 bytes
#                3 Dir(s)  50.735.960.064 bytes free

# %%
#pandas excel dosyalarını okumak için xlrd motorunu kullanır

# %%
#pip install xlrd
# Out:
# Collecting xlrd
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv('advertising.csv')

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
#df = pd.read_excel('advertising.xls', engine='xlrd')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
#korelasyon
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
#Scikit Learn kütüphanesi vew gerekli modülleri yükle
#veri setini bölmek için
from sklearn.model_selection import train_test_split

#ölçeklendirme (Veri ön işleme)
from sklearn.preprocessing import StandardScaler

#Model
from sklearn.linear_model import LinearRegression

#Değerlendirme
from sklearn.metrics import mean_squared_error, r2_score

# %%
## Özellikleri (X) ve hedefi sütununu belirle (y)
X=df[['TV','Radio','Newspaper']]
#X=df.drop('Sales',axis=1)
y=df['Sales']

# %%
## Veri Setini Eğitim ve Test Olarak Böl
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=.2,
                                              random_state=42)

# %%
## Modeli oluştur
model=LinearRegression()

# %%
## modeli eğit
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#eğitilmiş modelde testleri yap
y_pred=model.predict(X_test)

# %%
X_test, y_pred
# Out:
# (        TV  Radio  Newspaper
#  95   163.3   31.6       52.9
#  15   195.4   47.7       52.9
#  30   292.9   28.3       43.2
#  158   11.7   36.9       45.2
#  128  220.3   49.0        3.2
#  115   75.1   35.0       52.7
#  69   216.8   43.9       27.2
#  170   50.0   11.6       18.4
#  174  222.4    3.4       13.1
#  45   175.1   22.5       31.5
#  66    31.5   24.6        2.2
#  182   56.2    5.7       29.7
#  165  234.5    3.4       84.8
#  78     5.4   29.9        9.4
#  186  139.5    2.1       26.6
#  177  170.2    7.8       35.2
#  56     7.3   28.1       41.4
#  152  197.6   23.3       14.2
#  82    75.3   20.3       32.5
#  68   237.4   27.5       11.0
#  124  229.5   32.3       74.2
#  16    67.8   36.6      114.0
#  148   38.0   40.3       11.9
#  93   250.9   36.5       72.3
#  65    69.0    9.3        0.9
#  60    53.5    2.0       21.4
#  84   213.5   43.0       33.8
#  67   139.3   14.5       10.2
#  125   87.2   11.8       25.9
#  132    8.4   27.2        2.1
#  9    199.8    2.6       21.2
#  18    69.2   20.5       18.3
#  55   198.9   49.4       60.0
#  75    16.9   43.7       89.4
#  150  280.7   13.9       37.0
#  104  238.2   34.3        5.3
#  135   48.3   47.0        8.5
#  137  273.7   28.9       59.7
#  164  117.2   14.7        5.4
#  76    27.5    1.6       20.7,
#  array([16.4080242 , 20.88988209, 21.55384318, 10.60850256, 22.11237326,
#         13.10559172, 21.05719192,  7.46101034, 13.60634581, 15.15506967,
#          9.04831992,  6.65328312, 14.34554487,  8.90349333,  9.68959028,
#         12.16494386,  8.73628397, 16.26507258, 10.27759582, 18.83109103,
#         19.56036653, 13.25103464, 12.33620695, 21.30695132,  7.82740305,
#          5.80957448, 20.75753231, 11.98138077,  9.18349576,  8.5066991 ,
#         12.46646769, 10.00337695, 21.3876709 , 12.24966368, 18.26661538,
#         20.13766267, 14.05514005, 20.85411186, 11.0174441 ,  4.56899622]))

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    11.5
# 45     14.9
# 66      9.5
# 182     8.7
# 165    11.9
# 78      5.3
# 186    10.3
# 177    11.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65      9.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      10.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# Name: Sales, dtype: float64

# %%
model_predict_actual=pd.DataFrame({'Test':y_test,
                                 'Tahmin':y_pred})

# %%
model_predict_actual
# Out:
#      Test     Tahmin
# 95   16.9  16.408024
# 15   22.4  20.889882
# 30   21.4  21.553843
# 158   7.3  10.608503
# 128  24.7  22.112373
# 115  12.6  13.105592
# 69   22.3  21.057192
# 170   8.4   7.461010
# 174  11.5  13.606346
# 45   14.9  15.155070
# 66    9.5   9.048320
# 182   8.7   6.653283
# 165  11.9  14.345545
# 78    5.3   8.903493
# 186  10.3   9.689590
# 177  11.7  12.164944
# 56    5.5   8.736284
# 152  16.6  16.265073
# 82   11.3  10.277596
# 68   18.9  18.831091
# 124  19.7  19.560367
# 16   12.5  13.251035
# 148  10.9  12.336207
# 93   22.2  21.306951
# 65    9.3   7.827403
# 60    8.1   5.809574
# 84   21.7  20.757532
# 67   13.4  11.981381
# 125  10.6   9.183496
# 132   5.7   8.506699
# 9    10.6  12.466468
# 18   11.3  10.003377
# 55   23.7  21.387671
# 75    8.7  12.249664
# 150  16.1  18.266615
# 104  20.7  20.137663
# 135  11.6  14.055140
# 137  20.8  20.854112
# 164  11.9  11.017444
# 76    6.9   4.568996

# %%
model_predict_actual['Error']=abs(model_predict_actual['Test']-model_predict_actual['Tahmin'])
model_predict_actual
# Out:
#      Test     Tahmin     Error
# 95   16.9  16.408024  0.491976
# 15   22.4  20.889882  1.510118
# 30   21.4  21.553843  0.153843
# 158   7.3  10.608503  3.308503
# 128  24.7  22.112373  2.587627
# 115  12.6  13.105592  0.505592
# 69   22.3  21.057192  1.242808
# 170   8.4   7.461010  0.938990
# 174  11.5  13.606346  2.106346
# 45   14.9  15.155070  0.255070
# 66    9.5   9.048320  0.451680
# 182   8.7   6.653283  2.046717
# 165  11.9  14.345545  2.445545
# 78    5.3   8.903493  3.603493
# 186  10.3   9.689590  0.610410
# 177  11.7  12.164944  0.464944
# 56    5.5   8.736284  3.236284
# 152  16.6  16.265073  0.334927
# 82   11.3  10.277596  1.022404
# 68   18.9  18.831091  0.068909
# 124  19.7  19.560367  0.139633
# 16   12.5  13.251035  0.751035
# 148  10.9  12.336207  1.436207
# 93   22.2  21.306951  0.893049
# 65    9.3   7.827403  1.472597
# 60    8.1   5.809574  2.290426
# 84   21.7  20.757532  0.942468
# 67   13.4  11.981381  1.418619
# 125  10.6   9.183496  1.416504
# 132   5.7   8.506699  2.806699
# 9    10.6  12.466468  1.866468
# 18   11.3  10.003377  1.296623
# 55   23.7  21.387671  2.312329
# 75    8.7  12.249664  3.549664
# 150  16.1  18.266615  2.166615
# 104  20.7  20.137663  0.562337
# 135  11.6  14.055140  2.455140
# 137  20.8  20.854112  0.054112
# 164  11.9  11.017444  0.882556
# 76    6.9   4.568996  2.331004

# %%
model_predict_actual.mean()
# Out:
# Test      13.712500
# Tahmin    13.810021
# Error      1.460757
# dtype: float64

# %%
## Değerlendirme
r2=r2_score(y_test,y_pred)
r2 # 1  e ne kadar yakın olursa model o kadar iyidir
# Out:
# 0.899438024100912

# %%
## hatayı hesapla
print ('MSE',mean_squared_error(y_test,y_pred))
# Out:
# MSE 3.1740973539761033

# %% [markdown]
# ![image.png](attachment:e9c726d9-9c6d-4c04-97a4-469f11a532b2.png)

# %%
print ('RMSE',mean_squared_error(y_test,y_pred)**.5)
# Out:
# RMSE 1.78159966153345

# %% [markdown]
# ![image.png](attachment:e8bb4d9d-e091-4a18-a8c7-1751119a8cd0.png)

# %%
#RMSE=MSE**.5

# %% [markdown]
# Bu formülün katsayılarını ve sabit sayılarını bulmaya çalışıyoruz.
#
# satışlar= Sabit+ katsayı1*Tv+ katsayı2*Radio+ katsayı3*Newspaper + Hata

# %%
print('Katsayılar', model.coef_)
# Out:
# Katsayılar [0.04472952 0.18919505 0.00276111]

# %%
# TV, Radio ve Newspaper

# %%
#sabit terim
model.intercept_
# Out:
# 2.979067338122629

# %%
X_test
# Out:
#         TV  Radio  Newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# 115   75.1   35.0       52.7
# 69   216.8   43.9       27.2
# 170   50.0   11.6       18.4
# 174  222.4    3.4       13.1
# 45   175.1   22.5       31.5
# 66    31.5   24.6        2.2
# 182   56.2    5.7       29.7
# 165  234.5    3.4       84.8
# 78     5.4   29.9        9.4
# 186  139.5    2.1       26.6
# 177  170.2    7.8       35.2
# 56     7.3   28.1       41.4
# 152  197.6   23.3       14.2
# 82    75.3   20.3       32.5
# 68   237.4   27.5       11.0
# 124  229.5   32.3       74.2
# 16    67.8   36.6      114.0
# 148   38.0   40.3       11.9
# 93   250.9   36.5       72.3
# 65    69.0    9.3        0.9
# 60    53.5    2.0       21.4
# 84   213.5   43.0       33.8
# 67   139.3   14.5       10.2
# 125   87.2   11.8       25.9
# 132    8.4   27.2        2.1
# 9    199.8    2.6       21.2
# 18    69.2   20.5       18.3
# 55   198.9   49.4       60.0
# 75    16.9   43.7       89.4
# 150  280.7   13.9       37.0
# 104  238.2   34.3        5.3
# 135   48.3   47.0        8.5
# 137  273.7   28.9       59.7
# 164  117.2   14.7        5.4
# 76    27.5    1.6       20.7

# %%
2.979067338122629+(0.04472952*163.3)+(0.18919505*31.6)+ (0.00276111*52.9)
# Out:
# 16.40802425312263

# %%
y_pred[0]
# Out:
# 16.408024203228628

# %%
## İstatistiksel model olarak 
import statsmodels.formula.api as sm
model=sm.ols(formula="Sales~TV+Radio+Newspaper",data=df).fit()
coef=model.params
fit=coef[0]+coef[1]*df.TV+coef[2]*df.Radio+coef[3]*df.Newspaper
res=df.Sales-fit
print(fit)
print(res)
print(model.summary())
# Out:
# 0      20.523974
# 1      12.337855
# 2      12.307671
# 3      17.597830
# 4      13.188672
#          ...
# 195     5.370342
# 196     8.165312
# 197    12.785921
# 198    23.767321
# 199    15.173196
# Length: 200, dtype: float64
# 0      1.576026
# 1     -1.937855
# 2     -3.007671
# 3      0.902170
# 4     -0.288672
#          ...
# 195    2.229658
# 196    1.534688
# 197    0.014079
# 198    1.732679
# 199   -1.773196
# Length: 200, dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Thu, 12 Sep 2024   Prob (F-statistic):           1.58e-96
# Time:                        22:28:45   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# TV             0.0458      0.001     32.809      0.000       0.043       0.049
# Radio          0.1885      0.009     21.893      0.000       0.172       0.206
# Newspaper     -0.0010      0.006     -0.177      0.860      -0.013       0.011
# ==============================================================================
# Omnibus:                       60.414   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.241
# Skew:                          -1.327   Prob(JB):                     1.44e-33
# Kurtosis:                       6.332   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Standartlaştırma
sc=StandardScaler()
X_train_sc=sc.fit_transform(X_train)
X_test_sc=sc.fit_transform(X_test)

# %% [markdown]
# ![image.png](attachment:f45fa542-3e98-44fe-a98d-093e0ad382ac.png)

# %%
model_lr=LinearRegression()

# %%
model_lr.fit(X_train_sc,y_train)
# Out:
# LinearRegression()

# %%
y_pred2=model_lr.predict(X_test_sc)
mean_squared_error(y_pred2,y_test)
# Out:
# 3.588163345396854

# %%
mean_squared_error(y_pred2,y_test)**.5
# Out:
# 1.8942447955311514

# %%
#Normalleştirme
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train_nrm=scaler.fit_transform(X_train)
X_test_nrm=scaler.fit_transform(X_test)
model_lr.fit(X_train_nrm,y_train)
y_pred3=model_lr.predict(X_test_nrm)
mean_squared_error(y_pred3,y_test)
# Out:
# 3.140052922577892

# %% [markdown]
# ![image.png](attachment:a47d65ca-b8cd-4020-af35-5713158524cd.png)

# %%
# Lineer Regresyon çizgisi ve görselleştirme
plt.plot(y_pred3,y_pred3, color='red', linestyle="--")
plt.scatter(y_test,y_pred3, color='green')
